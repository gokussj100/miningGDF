# %%
from  fiona import listlayers
import os

indiaMaps=os.path.join('maps','indiaMaps_24383.gpkg')

#layers del mapa 
listlayers(indiaMaps)
# Out:
# ['airports',
#  'states',
#  'municipalities',
#  'country',
#  'cities',
#  'rivers',
#  'border']

# %%
# Leyendo la data:
import os
import geopandas as gpd

states=gpd.read_file(indiaMaps,layer='states')
municipalities=gpd.read_file(indiaMaps,layer='municipalities')
airports=gpd.read_file(indiaMaps,layer='airports')
rivers=gpd.read_file(indiaMaps,layer='rivers')
border=gpd.read_file(indiaMaps,layer='border')

# %%
import pandas as pd 

portsFile=os.path.join('data','UpdatedPub150.csv')

infoseaports=pd.read_csv(portsFile)
#columnas de datos de los aeropuertos
infoseaports.columns.to_list()
# Out:
# ['World Port Index Number',
#  'Region Name',
#  'Main Port Name',
#  'Alternate Port Name',
#  'UN/LOCODE',
#  'Country Code',
#  'World Water Body',
#  'IHO S-130 Sea Area',
#  'Sailing Direction or Publication',
#  'Publication Link',
#  'Standard Nautical Chart',
#  'IHO S-57 Electronic Navigational Chart',
#  'IHO S-101 Electronic Navigational Chart',
#  'Digital Nautical Chart',
#  'Tidal Range (m)',
#  'Entrance Width (m)',
#  'Channel Depth (m)',
#  'Anchorage Depth (m)',
#  'Cargo Pier Depth (m)',
#  'Oil Terminal Depth (m)',
#  'Liquified Natural Gas Terminal Depth (m)',
#  'Maximum Vessel Length (m)',
#  'Maximum Vessel Beam (m)',
#  'Maximum Vessel Draft (m)',
#  'Offshore Maximum Vessel Length (m)',
#  'Offshore Maximum Vessel Beam (m)',
#  'Offshore Maximum Vessel Draft (m)',
#  'Harbor Size',
#  'Harbor Type',
#  'Harbor Use',
#  'Shelter Afforded',
#  'Entrance Restriction - Tide',
#  'Entrance Restriction - Heavy Swell',
#  'Entrance Restriction - Ice',
# ...

# %%
#Renombramos el Main Port Name por portName
infoseaports.rename(columns={'Main Port Name':'portName'},inplace=True)
infoseaports=infoseaports.loc[:,['portName', 'Country Code','Latitude', 'Longitude']]
infoseaports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3739 entries, 0 to 3738
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   portName      3739 non-null   object
#  1   Country Code  3739 non-null   object
#  2   Latitude      3739 non-null   float64
#  3   Longitude     3739 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 117.0+ KB

# %%
# some rows
infoseaports.head()
# Out:
#                 portName   Country Code   Latitude   Longitude
# 0                 Maurer  United States  40.533333  -74.250000
# 1  Mangkasa Oil Terminal      Indonesia  -2.733333  121.066667
# 2                Iharana     Madagascar -13.350000   50.000000
# 3                Andoany     Madagascar -13.400000   48.300000
# 4            Chake Chake       Tanzania  -5.250000   39.766667

# %%
#Puntos espaciales
seaports=gpd.GeoDataFrame(data=infoseaports.copy(),
                           geometry=gpd.points_from_xy(infoseaports.Longitude,
                                                       infoseaports.Latitude), 
                          crs=4326) 

seaports_ind=seaports[seaports['Country Code']=='India'].copy()
seaports_ind.reset_index(drop=True, inplace=True)
seaports_ind_24383=seaports_ind.to_crs(24383)

# %%
airports.columns
# Out:
# Index(['name', 'kind', 'latitude_deg', 'longitude_deg', 'elevation_ft',
#        'region_name', 'municipality', 'geometry'],
#       dtype='object')

# %%
airports.rename(columns={'kind':'type'},inplace=True)
airports.columns
# Out:
# Index(['name', 'type', 'latitude_deg', 'longitude_deg', 'elevation_ft',
#        'region_name', 'municipality', 'geometry'],
#       dtype='object')

# %%
# Filtrar aeropuertos grandes usando la columna 'kind'
largeAirports = airports[airports['type'] == 'large_airport']
largeAirports.reset_index(drop=True, inplace=True)
#plotting
base=largeAirports.plot(color='red',marker="^")
seaports_ind_24383.plot(ax=base,alpha=1,markersize=3)
# Out:
# <Axes: >

# %%
seaports_ind_24383.geometry.apply\
(lambda g: largeAirports.geometry.distance(g)/1000)
# Out:
#               0            1            2            3            4  \
# 0   1461.369200   942.236379   365.747602   495.546641  1058.094799
# 1   1031.686779   559.171981  1588.734639  1392.629924  1994.068490
# 2   2510.360265  2287.061633  1374.185094  1641.984883  1303.144300
# 3    966.399643   224.155582  1206.155073  1029.599691  1666.238739
# 4    997.194118   490.187358  1515.635478  1323.696693  1922.368506
# 5   1011.282012   525.928355  1553.371893  1359.615201  1957.159928
# 6   1079.837716   549.495272  1582.612043  1380.583472  2023.729691
# 7   1114.250304   332.580799  1366.279403  1159.826166  1905.165653
# 8   1034.207692   506.359355  1536.483695  1339.761420  1962.435264
# 9   1024.089168   492.019787  1521.087545  1325.636445  1945.198887
# 10   948.740182   522.395461  1539.299602  1353.707413  1903.240586
# 11  1104.875016   446.703950  1480.613838  1274.862528  1975.816875
# 12   937.018884   502.383586  1516.279406  1332.412222  1879.259780
# ...

# %%
seaports_ind_24383.set_index('portName').geometry.apply\
(lambda g: largeAirports.set_index('name').geometry.distance(g)/1000)
# Out:
# name                                 Indira Gandhi International Airport  \
# portName
# Machilipatnam                                                1461.369200
# Mandvi                                                       1031.686779
# Port Blair                                                   2510.360265
# Hazira                                                        966.399643
# Bedi                                                          997.194118
# Mundra                                                       1011.282012
# Okha                                                         1079.837716
# Veraval                                                      1114.250304
# Vadinar Terminal                                             1034.207692
# Sikka                                                        1024.089168
# Kandla                                                        948.740182
# Porbandar                                                    1104.875016
# ...

# %%
seaports_ind_24383.set_index('portName').geometry.apply\
(lambda g: largeAirports.set_index('name').geometry.distance(g)/1000).\
sort_index(axis=0).sort_index(axis=1)
# Out:
# name                                 Chennai International Airport  \
# portName
# Azhikal (Azhikkal)                                      540.160893
# Baleshwar                                              1188.875181
# Bedi                                                   1515.635478
# Belekeri                                                665.086392
# Beypore                                                 516.055359
# Bhavnagar                                              1291.120389
# Calcutta                                               1373.267039
# Calicut (Kozhikode)                                     515.824382
# Chennai (Madras)                                         18.663599
# Cuddalore                                               147.338651
# Dahej                                                  1264.735667
# Dhamra                                                 1132.248617
# Gangavaram                                              611.486414
# ...

# %%
distanceMatrixKM_sea_air_ind= seaports_ind_24383.set_index('portName').geometry.apply\
                          (lambda g: largeAirports.set_index('name').geometry.distance(g)/1000).\
                          sort_index(axis=0).sort_index(axis=1)

# %%
distanceMatrixKM_sea_air_ind.mean(axis=1).sort_values(ascending=True)
# Out:
# portName
# Belekeri                                774.955646
# Panaji                                  775.773234
# Marmagao                                776.929274
# Karwar                                  777.595087
# Honavar                                 779.427270
# Krishnapatnam                           802.246345
# Ratnagiri                               805.270747
# Jaigarh Bay                             810.792591
# New Mangalore                           811.959304
# Port Dabhol                             815.699176
# Kattupalli Port                         829.030679
# Kamarajar Port                          829.499564
# Chennai (Madras)                        830.966559
# Azhikal (Azhikkal)                      836.465968
# Jawaharlal Nehru Port (Nhava Shiva)     843.492011
# Mumbai (Bombay)                         847.239287
# Machilipatnam                           850.361480
# Machilipatnam                           851.324996
# ...

# %%
SomeStats=pd.DataFrame()
SomeStats['mean']=distanceMatrixKM_sea_air_ind.mean(axis=1)
SomeStats['min']=distanceMatrixKM_sea_air_ind.min(axis=1)
SomeStats['max']=distanceMatrixKM_sea_air_ind.max(axis=1)

SomeStats.head(10)
# Out:
#                             mean         min          max
# portName
# Azhikal (Azhikkal)    836.465968  231.295370  1872.509279
# Baleshwar            1327.848720  204.639172  1800.650069
# Bedi                 1158.680560  106.172843  1922.368506
# Belekeri              774.955646   88.703543  1745.557638
# Beypore               860.350719  130.007011  1953.876244
# Bhavnagar             995.880106  142.683241  1699.457641
# Calcutta             1455.040751   16.708216  1984.663352
# Calicut (Kozhikode)   856.921270  139.795393  1944.940005
# Chennai (Madras)      830.966559   18.663599  1767.871483
# Cuddalore             873.828620  147.338651  1909.199677

# %%
distanceMatrixKM_sea_air_ind.idxmax(axis=1)
# Out:
# portName
# Azhikal (Azhikkal)                                   Indira Gandhi International Airport
# Baleshwar                                       Thiruvananthapuram International Airport
# Bedi                                   Netaji Subhash Chandra Bose International Airport
# Belekeri                               Netaji Subhash Chandra Bose International Airport
# Beypore                                              Indira Gandhi International Airport
# Bhavnagar                              Netaji Subhash Chandra Bose International Airport
# Calcutta                                        Thiruvananthapuram International Airport
# Calicut (Kozhikode)                                  Indira Gandhi International Airport
# Chennai (Madras)                                     Indira Gandhi International Airport
# Cuddalore                                            Indira Gandhi International Airport
# ...

# %%
distanceMatrixKM_sea_air_ind.idxmax(axis=0)
# Out:
# name
# Chennai International Airport                            Mandvi
# Chhatrapati Shivaji International Airport            Port Blair
# Cochin International Airport                           Calcutta
# Dabolim Airport                                      Port Blair
# Indira Gandhi International Airport                  Port Blair
# Kempegowda International Airport                     Port Blair
# Netaji Subhash Chandra Bose International Airport          Okha
# Rajiv Gandhi International Airport                   Port Blair
# Rajkot International Airport                         Port Blair
# Thiruvananthapuram International Airport               Calcutta
# dtype: object

# %%
distanceMatrixKM_sea_air_ind.idxmin(axis=1)
# Out:
# portName
# Azhikal (Azhikkal)                                          Cochin International Airport
# Baleshwar                              Netaji Subhash Chandra Bose International Airport
# Bedi                                                        Rajkot International Airport
# Belekeri                                                                 Dabolim Airport
# Beypore                                                     Cochin International Airport
# Bhavnagar                                                   Rajkot International Airport
# Calcutta                               Netaji Subhash Chandra Bose International Airport
# Calicut (Kozhikode)                                         Cochin International Airport
# Chennai (Madras)                                           Chennai International Airport
# Cuddalore                                                  Chennai International Airport
# ...

# %%
distanceMatrixKM_sea_air_ind.idxmin(axis=0)
# Out:
# name
# Chennai International Airport                        Chennai (Madras)
# Chhatrapati Shivaji International Airport             Mumbai (Bombay)
# Cochin International Airport                           Kochi (Cochin)
# Dabolim Airport                                              Marmagao
# Indira Gandhi International Airport                             Dahej
# Kempegowda International Airport                          Pondicherry
# Netaji Subhash Chandra Bose International Airport            Calcutta
# Rajiv Gandhi International Airport                      Machilipatnam
# Rajkot International Airport                                 Navlakhi
# Thiruvananthapuram International Airport                   Trivandrum
# dtype: object

# %%
rivers
# Out:
#           NAME SYSTEM                                           geometry
# 0       Ganges   None  LINESTRING (2746385.667 3039019.617, 2737084.3...
# 1  Brahmaputra   None  LINESTRING (4285762.355 2877568.136, 4267484.9...
# 2        Indus   None  MULTILINESTRING ((1521673.218 2251980.508, 152...

# %%
rivers[rivers.NAME.str.contains('Ganges')]
# Out:
#      NAME SYSTEM                                           geometry
# 0  Ganges   None  LINESTRING (2746385.667 3039019.617, 2737084.3...

# %%
rivers[rivers.NAME.str.contains('Ganges')].iloc[0].geometry.distance(largeAirports.set_index('name').geometry)/1000
# Out:
# name
# Indira Gandhi International Airport                   131.952458
# Chhatrapati Shivaji International Airport            1157.101193
# Chennai International Airport                        1389.541522
# Kempegowda International Airport                     1435.178652
# Netaji Subhash Chandra Bose International Airport     259.091333
# Dabolim Airport                                      1420.450230
# Rajiv Gandhi International Airport                    991.900235
# Cochin International Airport                         1800.038063
# Thiruvananthapuram International Airport             1957.153297
# Rajkot International Airport                         1029.260421
# Name: geometry, dtype: float64

# %%
distanceMatrixKM_riv_air_ind=rivers.set_index('NAME').geometry.apply\
(lambda g: largeAirports.set_index('name').geometry.distance(g)/1000).\
sort_index(axis=0).sort_index(axis=1)
distanceMatrixKM_riv_air_ind
# Out:
# name         Chennai International Airport  \
# NAME
# Brahmaputra                    1718.374132
# Ganges                         1389.541522
# Indus                          1745.427710
#
# name         Chhatrapati Shivaji International Airport  \
# NAME
# Brahmaputra                                1914.751600
# Ganges                                     1157.101193
# Indus                                       715.395723
#
# name         Cochin International Airport  Dabolim Airport  \
# NAME
# Brahmaputra                   2217.136237      2025.338268
# Ganges                        1800.038063      1420.450230
# Indus                         1747.773319      1107.966894
#
# name         Indira Gandhi International Airport  \
# NAME
# Brahmaputra                          1366.905266
# Ganges                                131.952458
# Indus                                 576.590749
#
# name         Kempegowda International Airport  \
# NAME
# ...

# %%
distanceMatrixKM_riv_air_ind.loc['Ganges'].sort_values()
# Out:
# name
# Indira Gandhi International Airport                   131.952458
# Netaji Subhash Chandra Bose International Airport     259.091333
# Rajiv Gandhi International Airport                    991.900235
# Rajkot International Airport                         1029.260421
# Chhatrapati Shivaji International Airport            1157.101193
# Chennai International Airport                        1389.541522
# Dabolim Airport                                      1420.450230
# Kempegowda International Airport                     1435.178652
# Cochin International Airport                         1800.038063
# Thiruvananthapuram International Airport             1957.153297
# Name: Ganges, dtype: float64

# %%
base_ind=largeAirports.explore(color='red',marker_kwds=dict(radius=10))
rivers[rivers.NAME.str.contains('Ganges')].explore(m=base_ind)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#Ejercicio 1 - Terminado

# %%
rivers
# Out:
#           NAME SYSTEM                                           geometry
# 0       Ganges   None  LINESTRING (2746385.667 3039019.617, 2737084.3...
# 1  Brahmaputra   None  LINESTRING (4285762.355 2877568.136, 4267484.9...
# 2        Indus   None  MULTILINESTRING ((1521673.218 2251980.508, 152...

# %%
#renombramos 
rivers.rename(columns={'NAME':'Rivers_name'},inplace=True)
rivers['Rivers_name'].values.tolist()
# Out:
# ['Ganges', 'Brahmaputra', 'Indus']

# %%
airports
# Out:
#                                                   name           type  \
# 0                  Indira Gandhi International Airport  large_airport
# 1            Chhatrapati Shivaji International Airport  large_airport
# 2                        Chennai International Airport  large_airport
# 3                     Kempegowda International Airport  large_airport
# 4    Netaji Subhash Chandra Bose International Airport  large_airport
# ..                                                 ...            ...
# 607                          Rushikonda Beach Heliport       heliport
# 608                              Oxygen Towers Helipad       heliport
# 609                                      MIRC Heliport       heliport
# 610                                     Yanam Heliport       heliport
# 611                                 Yingkiong Heliport       heliport
#
#      latitude_deg  longitude_deg  elevation_ft  \
# 0       28.555630      77.095190         777.0
# ...

# %%
distanceMatrixKM_riv_air_ind=rivers.set_index('Rivers_name').geometry.apply\
(lambda g: largeAirports.set_index('name').geometry.distance(g)/1000).\
sort_index(axis=0).sort_index(axis=1)
distanceMatrixKM_riv_air_ind
# Out:
# name         Chennai International Airport  \
# Rivers_name
# Brahmaputra                    1718.374132
# Ganges                         1389.541522
# Indus                          1745.427710
#
# name         Chhatrapati Shivaji International Airport  \
# Rivers_name
# Brahmaputra                                1914.751600
# Ganges                                     1157.101193
# Indus                                       715.395723
#
# name         Cochin International Airport  Dabolim Airport  \
# Rivers_name
# Brahmaputra                   2217.136237      2025.338268
# Ganges                        1800.038063      1420.450230
# Indus                         1747.773319      1107.966894
#
# name         Indira Gandhi International Airport  \
# Rivers_name
# Brahmaputra                          1366.905266
# Ganges                                131.952458
# Indus                                 576.590749
#
# name         Kempegowda International Airport  \
# Rivers_name
# ...

# %%
columna2=distanceMatrixKM_riv_air_ind.iloc[[1]]
columna2
# Out:
# name         Chennai International Airport  \
# Rivers_name
# Ganges                         1389.541522
#
# name         Chhatrapati Shivaji International Airport  \
# Rivers_name
# Ganges                                     1157.101193
#
# name         Cochin International Airport  Dabolim Airport  \
# Rivers_name
# Ganges                        1800.038063       1420.45023
#
# name         Indira Gandhi International Airport  \
# Rivers_name
# Ganges                                131.952458
#
# name         Kempegowda International Airport  \
# Rivers_name
# Ganges                            1435.178652
#
# name         Netaji Subhash Chandra Bose International Airport  \
# Rivers_name
# Ganges                                              259.091333
#
# name         Rajiv Gandhi International Airport  Rajkot International Airport  \
# Rivers_name
# Ganges                               991.900235                   1029.260421
#
# ...

# %%
# distancia entre el río seleccionado y cada aeropuerto mediano, considerando que su orden es ascendente
distanceMatrixKM_riv_air_ind.loc['Ganges'].sort_values()
# Out:
# name
# Indira Gandhi International Airport                   131.952458
# Netaji Subhash Chandra Bose International Airport     259.091333
# Rajiv Gandhi International Airport                    991.900235
# Rajkot International Airport                         1029.260421
# Chhatrapati Shivaji International Airport            1157.101193
# Chennai International Airport                        1389.541522
# Dabolim Airport                                      1420.450230
# Kempegowda International Airport                     1435.178652
# Cochin International Airport                         1800.038063
# Thiruvananthapuram International Airport             1957.153297
# Name: Ganges, dtype: float64

# %%
minsganges=fila2.idxmin(axis="columns")
minsganges
# Out:
# Rivers_name
# Ganges    Indira Gandhi International Airport
# dtype: object

# %%
maxganges=fila2.idxmax(axis="columns")
maxganges
# Out:
# Rivers_name
# Ganges    Thiruvananthapuram International Airport
# dtype: object

# %%
base=rivers[rivers.Rivers_name.str.contains('Ganges')].explore()
largeAirports[largeAirports.name.isin(minsganges)].explore(m=base,color='red',marker_kwds=dict(radius=10))
largeAirports[~largeAirports.name.isin(maxganges)].explore(m=base,color='blue',marker_kwds=dict(radius=5))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
rivers.convex_hull
# Out:
# 0    POLYGON ((3590218.745 2369064.620, 3060079.068...
# 1    POLYGON ((3767196.600 2417116.247, 3787518.927...
# 2    POLYGON ((1521673.218 2251980.508, 1521036.802...
# dtype: geometry

# %%
rivers.convex_hull.plot()
# Out:
# <Axes: >

# %%
rivers_hulls=rivers.convex_hull.to_frame()
rivers_hulls['Rivers_name']=['Brahmaputra', 'Ganges', 'Indus']
rivers_hulls.rename(columns={0:'geometry'},inplace=True)
rivers_hulls=rivers_hulls.set_geometry('geometry')
# crs
rivers_hulls.crs="EPSG:5641"
rivers_hulls
# Out:
#                                             geometry  Rivers_name
# 0  POLYGON ((3590218.745 2369064.620, 3060079.068...  Brahmaputra
# 1  POLYGON ((3767196.600 2417116.247, 3787518.927...       Ganges
# 2  POLYGON ((1521673.218 2251980.508, 1521036.802...        Indus

# %%
#Ejercicio 2
